# %%
print('Scratch for Matrix Factorization')
# Out:
# Scratch for Matrix Factorization

# %%
import pandas as pd

df_w_confidence = pd.read_csv('interactions-confidence.csv')
df_w_confidence.sort_values(by='CONFIDENCE', ascending=False).head(10)
# Out:
#         USER_ID  USER_IDX                               ITEM_ID  ITEM_IDX  \
# 181172    89596     84378  baca6570-15ab-43f8-a610-38a6efa502df      1822
# 46451     28432     26742  2f71e413-32fe-4f1d-a28b-8995be0685e8       445
# 186304    33108     31134  c09b78da-4234-4797-ad91-d28bdd54cee6      1877
# 87495     85814     80815  59719e89-9677-4201-8aad-fb0157bbd30c       865
# 223017    56787     53457  eb18ce0f-6a22-41e6-b04a-27daab2846d0      2278
# 144128    44566     41950  961a5529-ad78-4a28-8b3e-ea491c9a1646      1472
# 12362     99254     93504  0987bfa1-0a23-4b90-8882-8a6e9bd91e24        87
# 216541     9006      8458  e44cc0bf-d467-4aae-99fe-268e85eb0d1c      2207
# 169762    34545     32487  b1611948-8438-4332-bfed-8742c2780620      1722
# 13843     88457     83293  0bb3928f-adff-452e-97d8-b199b14d134f       104
#
#         CONFIDENCE
# 181172        40.0
# 46451         40.0
# 186304        40.0
# 87495         39.0
# 223017        38.0
# 144128        38.0
# ...

# %%
df_interactions = pd.read_csv('interactions.csv')
df_interactions
# df_w_confidence.sort_values(by='CONFIDENCE', ascending=False).head(10)
# Out:
#                                      ITEM_ID  USER_ID EVENT_TYPE   TIMESTAMP  \
# 0       b93b7b15-9bb3-407c-b80b-517e7c45e090    50495       View  1680513252
# 1       b93b7b15-9bb3-407c-b80b-517e7c45e090    50495       View  1680513255
# 2       e1c0c67b-4e01-47bd-bad9-db36ab87c4f7    33937       View  1680513271
# 3       e1c0c67b-4e01-47bd-bad9-db36ab87c4f7    33937       View  1680513279
# 4       b5daf920-8f69-4603-9ccb-1d7f2b77656e    39756       View  1680513287
# ...                                      ...      ...        ...         ...
# 799995  b57916d2-bc8f-440a-970e-b7413a9122aa    40820       View  1686720116
# 799996  b57916d2-bc8f-440a-970e-b7413a9122aa    40820       View  1686720127
# 799997  f7682a3c-fd50-4225-8bb7-3b82d815c37a    10307       View  1686720138
# 799998  f7682a3c-fd50-4225-8bb7-3b82d815c37a    10307       View  1686720146
# 799999  0790267c-c708-424d-81f5-46903a9c8444    91060       View  1686720154
#
#        DISCOUNT
# 0            No
# ...

# %%
ax = df_interactions['EVENT_TYPE'].value_counts().plot(kind='bar',
                                                       figsize=(8,4),
                                                       title="Frequency for each Event Type",
                                                        rot=0)
# ax.set_xlabel("Event Types")
ax.set_ylabel("Frequency")
for bars in ax.containers:
    ax.bar_label(bars)
